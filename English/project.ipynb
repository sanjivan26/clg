# %%
import pandas as pd
import numpy as np

# %%
dataset=pd.read_csv(r"project.csv",sep=",")

# %%
df=pd.DataFrame(dataset)

# %%
df.pop('Q1')
df.pop('Unnamed: 5')
df.pop('Unnamed: 7')
df.pop('Unnamed: 9')
df.pop('Unnamed: 11')
df.pop('Unnamed: 13')
df.pop('Unnamed: 15')
df.pop('Unnamed: 17')
df.pop('Unnamed: 19')
df.pop('Unnamed: 21')
df.pop('Unnamed: 23')
df.pop('Unnamed: 25')
df.pop('Unnamed: 27')
df.pop('Unnamed: 29')
df.pop('Unnamed: 31')
df.pop('Unnamed: 33')
df.pop('Unnamed: 34')
df.pop('Unnamed: 36')
df.pop('Unnamed: 38')
df.pop('Unnamed: 40')
df.pop('Unnamed: 42')
# Out:
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN
# 5    NaN
# 6    NaN
# 7    NaN
# 8    NaN
# 9    NaN
# 10   NaN
# 11   NaN
# 12   NaN
# 13   NaN
# 14   NaN
# 15   NaN
# 16   NaN
# 17   NaN
# 18   NaN
# 19   NaN
# 20   NaN
# 21   NaN
# 22   NaN
# 23   NaN
# 24   NaN
# 25   NaN
# 26   NaN
# 27   NaN
# 28   NaN
# 29   NaN
# 30   NaN
# 31   NaN
# 32   NaN
# 33   NaN
# 34   NaN
# 35   NaN
# 36   NaN
# 37   NaN
# 38   NaN
# 39   NaN
# 40   NaN
# 41   NaN
# 42   NaN
# 43   NaN
# 44   NaN
# 45   NaN
# 46   NaN
# 47   NaN
# 48   NaN
# 49   NaN
# 50   NaN
# 51   NaN
# Name: Unnamed: 42, dtype: float64

# %%
df.columns
# 0-2 : misc
# 3-22 : questions
# 23-26 : direct
# 27 : email(nan)
# Out:
# Index(['Timestamp', 'Name', 'Age',
#        'I enjoy energetic, group conversations over one-on-one conversations.',
#        'I explore deeper meanings and potential outcomes instead of taking things at face value.',
#        'I make decisions based on logic and reason over empathy and feeling.',
#        'I plan tasks ahead of time, usually completing them well before the deadline.',
#        'I'm more reserved and like to keep to myself.',
#        'I prioritize being practical and realistic over being imaginative and innovative.',
#        'I'd rather be straight-forward than sugarcoat things.',
#        'I prefer unplanned activities over following a schedule.',
#        'I prefer calm, quiet surroundings over loud, vibrant ones.',
#        'I enjoy exploring new ideas and viewpoints.',
#        'People often tell me that I'm blunt.',
#        'I have a fixed definition what is right and wrong.',
#        'I speak up when I believe it's necessary.',
# ...

# %%
asc = {"Strongly Disagree":1,"Disagree":2,"Neutral":3,"Agree":4,"Strongly Agree":5}
desc = {"Strongly Disagree":5,"Disagree":4,"Neutral":3,"Agree":2,"Strongly Agree":1}

# %%
#df['Extroverted%']=asc[df['I enjoy energetic, group conversations over one-on-one conversations.']]+desc[df['I\'m more reserved and like to keep to myself.']]+desc[df['I prefer calm, quiet surroundings over loud, vibrant ones.']]+asc[df['I speak up when I believe it\'s necessary.']]+asc[df['I\'m usually the one who plans and co-ordinates activities in my group.']]
#df['Sensing%']=desc[df['I explore deeper meanings and potential outcomes instead of taking things at face value.']]+asc[df['I prioritize being practical and realistic over being imaginative and innovative.']]+desc[df['I enjoy exploring new ideas and viewpoints.']]+desc[df['I spend a lot of time thinking about what could happen in the future.']]+desc[df['I enjoy philosophical debates and conversations.']]
#df['Thinking%']=asc[df['I make decisions based on logic and reason over empathy and feeling.']]+asc[df['I\'d rather be straight-forward than sugarcoat things.']]+asc[df['People often tell me that I\'m blunt.']]+desc[df['I get hurt by others\' words easily.']]+desc[df['People\'s stories and emotions speak to me louder than numbers or data.']]
#df['Judging%']=asc[df['I plan tasks ahead of time, usually completing them well before the deadline.']]+desc[df['I prefer unplanned activities over following a schedule.']]+asc[df['I have a fixed definition what is right and wrong.']]+desc[df['I\'m spontaneous and feel like plans suffocate my style.']]+desc[df['I struggle with deadlines']]

# %%
df['Extroverted%']=0
df['Introverted%']=0
for i in df.index:
    df.iloc[i,28]=(asc[df.iloc[i,3]]+desc[df.iloc[i,7]]+desc[df.iloc[i,11]]+asc[df.iloc[i,15]]+asc[df.iloc[i,19]])*4
    df.iloc[i,29]=100-df.iloc[i,28]

# %%
df['Sensing%']=0
df['Intuitive%']=0
for i in df.index:
    df.iloc[i,30]=(desc[df.iloc[i,4]]+asc[df.iloc[i,8]]+desc[df.iloc[i,12]]+desc[df.iloc[i,16]]+desc[df.iloc[i,20]])*4
    df.iloc[i,31]=100-df.iloc[i,30]

# %%
df['Thining%']=0
df['Feeling%']=0
for i in df.index:
    df.iloc[i,32]=(asc[df.iloc[i,5]]+asc[df.iloc[i,9]]+asc[df.iloc[i,13]]+desc[df.iloc[i,17]]+desc[df.iloc[i,21]])*4
    df.iloc[i,33]=100-df.iloc[i,32]

# %%
df['Judging%']=0
df['Perceptiveness%']=0
for i in df.index:
    df.iloc[i,34]=(asc[df.iloc[i,6]]+desc[df.iloc[i,10]]+asc[df.iloc[i,14]]+desc[df.iloc[i,18]]+desc[df.iloc[i,22]])*4
    df.iloc[i,35]=100-df.iloc[i,34]

# %%
df.head()
# Out:
#            Timestamp              Name    Age  \
# 0  4/3/2024 18:04:21  Krishna Cheliaah  17-19
# 1   4/4/2024 8:23:47          Kesavram  17-19
# 2  4/4/2024 14:01:19          Sanjivan  17-19
# 3  4/4/2024 14:08:38         KANNAPPAN  17-19
# 4  4/4/2024 14:09:34          Hariesh   17-19
#
#   I enjoy energetic, group conversations over one-on-one conversations.  \
# 0                                           Disagree
# 1                                  Strongly Disagree
# 2                                           Disagree
# 3                                            Neutral
# 4                                     Strongly Agree
#
#   I explore deeper meanings and potential outcomes instead of taking things at face value.  \
# 0                                              Agree
# 1                                     Strongly Agree
# 2                                     Strongly Agree
# 3                                              Agree
# ...

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(df['Extroverted%'])
# Out:
# (array([ 2.,  1.,  1., 10.,  5., 12., 12.,  4.,  4.,  1.]),
#  array([24. , 30.4, 36.8, 43.2, 49.6, 56. , 62.4, 68.8, 75.2, 81.6, 88. ]),
#  <BarContainer object of 10 artists>)
