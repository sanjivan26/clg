# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
arr=np.array(np.random.rand(10000000))

# %%
plt.hist(arr)
# Out:
# (array([1003., 1011.,  930., 1008.,  972., 1016., 1006., 1033.,  980.,
#         1041.]),
#  array([7.98235689e-05, 1.00070287e-01, 2.00060750e-01, 3.00051213e-01,
#         4.00041676e-01, 5.00032140e-01, 6.00022603e-01, 7.00013066e-01,
#         8.00003529e-01, 8.99993992e-01, 9.99984456e-01]),
#  <BarContainer object of 10 artists>)
