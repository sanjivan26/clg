# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
import pandas as pd
import seaborn as sns
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

# %%
iris = load_iris()
data = iris.data
result = iris.target

# %%
df = pd.DataFrame(data)
df['Predict'] = result

# %%
# Initialize K-means with 3 clusters (since we know there are 3 species of iris in the dataset)
kmeans = KMeans(n_clusters=3, random_state=42)

# %%
# Fit K-means to the data
kmeans.fit(data)
# Out:
# KMeans(n_clusters=3, random_state=42)

# %%
# Getting the cluster centroids and labels
centroids = kmeans.cluster_centers_
labels = kmeans.labels_

# %%
# Visualizing the clusters
plt.figure(figsize=(10, 6))

# %%
# Plotting the clusters based on the first two features (sepal length and sepal width)
plt.scatter(data[labels == 0, 0], data[labels == 0, 1], c='red', label='Iris-setosa')
plt.scatter(data[labels == 1, 0], data[labels == 1, 1], c='blue', label='Iris-versicolour')
plt.scatter(data[labels == 2, 0], data[labels == 2, 1], c='green', label='Iris-virginica')

# Plotting the centroids
plt.scatter(centroids[:, 0], centroids[:, 1], c='black', marker='x', label='Centroids')
plt.xlabel('Sepal Length (cm)')
plt.ylabel('Sepal Width (cm)')
plt.title('K-means Clustering of Iris Dataset')
plt.legend()
plt.show()
